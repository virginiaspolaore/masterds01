# %%
maxdistance = 10
Temperature = 10.5
greet_ing = "pollo"
isRaining = True

print(maxdistance,Temperature,greet_ing,isRaining)
# Out:
# 10 10.5 pollo True

# %%
"""
1st_value -> first_value
Total$Amount -> total_amount
calcNum ->calc_num
Data-Entry ->data_entry
"""
# Out:
# '\n1st_value -> first_value\nTotal$Amount -> total_amount\ncalcNum ->calc_num\nData-Entry ->data_entry\n'

# %%
float(42)
# Out:
# 42.0

# %%
d = 3.14159

# %%
int(d)
# Out:
# 3

# %%
int(3.14159)
# Out:
# 3
