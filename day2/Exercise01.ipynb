# %%
if 10 > 50:
    print("Ten is bigger than five")
else:
    print("it's lower")
    
print("Today is sunny")
# Out:
# it's lower
# Today is sunny

# %%
if 10 > 5:
    print("Ten is bigger than five")
else:
    print("it's lower")
    
print("Today is sunny")
# Out:
# Ten is bigger than five
# Today is sunny

# %%
def sum(a,b):
    """
    This function receives two values taht are summed together
    """
    result = a+b # a is added to b and associated with "result"
    return result # we return the "result" variable

# %%
sum(10,20)
# Out:
# 30

# %%
sum("Mike", "Elisa")
# Out:
# 'MikeElisa'

# %%
sum("Mike", 50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 sum("Mike", 50)
#
# Cell In[17], line 2, in sum(a, b)
#       1 def sum(a,b):
# ----> 2     result = a+b
#       3     return result
#
# TypeError: can only concatenate str (not "int") to str

# %%
"Mike" * 100
# Out:
# '...'

# %%
age = 30

# %%
Age = 20

# %%
age
# Out:
# 30

# %%
Age
# Out:
# 20

# %%
building1 = "Church" # se lo cancello con l'ultimo simbolo di questa riga, building1 esiste ancora

# %%
building1_name = "Church" # snake syntax
building1Name = "Church" # camel syntax
building1_height = 100

building2_name = "Stadium"
building2_height = 200

building3_name = "Igloo"
building3_height = 1

# %%
print(building4_name)
build
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 print(building4_name)
#
# NameError: name 'building4_name' is not defined

# %%
age = 40.5

# %%
student_name = Maria
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 student_name = Maria
#
# NameError: name 'Maria' is not defined

# %%
student_name = "Maria"
print(student_name)
print(student_name+student_name)
# Out:
# Maria
# MariaMaria

# %%
type(student_name)
type(age)
# Out:
# float

# %%
dangerous = True

# %%
type(dangerous)
# Out:
# bool

# %%
type(3>5)
# Out:
# bool

# %%
d = str(dangerous)

# %%
type(d)
# Out:
# str

# %%
d
# Out:
# 'True'

# %%
s = "20A"

# %%
s+s
# Out:
# '20A20A'

# %%
int(s)+int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 int(s)+int(s)
#
# ValueError: invalid literal for int() with base 10: '20A'

# %%
a = 10
b = "Julie"
c = True
d = 3.5

# %%
type(d)
# Out:
# float

# %%
float(a)
# Out:
# 10.0

# %%
type(float(a))
# Out:
# float
