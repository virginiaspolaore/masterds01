# %%
def greet (name):
    name = name.upper()
    print(f"Hello {name}")

# %%
greet("Alice")
# Out:
# Hello ALICE

# %%
employee = "Salim"

greet (employee)
# Out:
# Hello SALIM

# %%
employee
# Out:
# 'Salim'

# %%
# !pip install numpy ==2.3, in realtà a me già funzionava import numpy sotto

# %%
import numpy

# %%
dir(numpy) # all the function available in numpy
# Out:
# ['False_',
#  'ScalarType',
#  'True_',
#  '_CopyMode',
#  '_NoValue',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__array_api_version__',
#  '__array_namespace_info__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__dir__',
#  '__doc__',
#  '__expired_attributes__',
#  '__file__',
#  '__former_attrs__',
#  '__future_scalars__',
#  '__getattr__',
#  '__loader__',
#  '__name__',
#  '__numpy_submodules__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_array_api_info',
#  '_core',
#  '_distributor_init',
#  '_expired_attrs_2_0',
#  '_globals',
#  '_int_extended_msg',
#  '_mat',
#  '_msg',
#  '_pyinstaller_hooks_dir',
#  '_pytesttester',
#  '_specific_msg',
#  '_type_info',
#  '_typing',
#  '_utils',
#  'abs',
#  'absolute',
#  'acos',
#  'acosh',
#  'add',
#  'all',
#  'allclose',
#  'amax',
#  'amin',
#  'angle',
#  'any',
#  'append',
#  'apply_along_axis',
#  'apply_over_axes',
#  'arange',
#  'arccos',
#  'arccosh',
#  'arcsin',
#  'arcsinh',
# ...

# %%
numpy.arange(start = 100, stop = 200, step = 33)
# Out:
# array([100, 133, 166, 199])

# %%
from numpy import arange # I imported arange and I can invocate, using without any prefix, vedi sotto

# %%
arange(start = 100, stop = 200, step = 33)
# Out:
# array([100, 133, 166, 199])

# %% [markdown]
# # Matplotlib

# %%
# !pip install matplotlib, qui già installato

# %%
import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [2,3,-50,100,11]

# %%
plt.plot(x,y) # create a line plot
plt.title("Sample Plot")
plt.xlabel("Days")
plt.ylabel("Rain mm")
plt.show()
